# %%
# This notebook will be used in co-op exclusive data
# That is, the home type from street easy was pre selected as coop

# %%
import numpy as np 
import pandas as pd 
df = pd.read_csv('data/medianAskingPrice_Coop.csv')
df.head(10)
# Out:
#               areaName    Borough      areaType   2010-01   2010-02   2010-03  \
# 0         All Downtown  Manhattan     submarket  749000.0  749000.0  699000.0
# 1          All Midtown  Manhattan     submarket  595000.0  597000.0  597000.0
# 2  All Upper East Side  Manhattan     submarket  900500.0  895000.0  895000.0
# 3  All Upper Manhattan  Manhattan     submarket  349000.0  349000.0  349500.0
# 4  All Upper West Side  Manhattan     submarket  729023.0  769500.0  787000.0
# 5              Astoria     Queens  neighborhood       NaN       NaN       NaN
# 6           Auburndale     Queens  neighborhood       NaN       NaN       NaN
# 7           Bath Beach   Brooklyn  neighborhood       NaN       NaN       NaN
# 8    Battery Park City  Manhattan  neighborhood       NaN       NaN       NaN
# 9            Bay Ridge   Brooklyn  neighborhood  272000.0  272000.0  274900.0
#
#     2010-04   2010-05   2010-06   2010-07  ...    2021-10    2021-11  \
# ...

# %%
# Define Neighborhoods of interest

myinterest = ['Chelsea','West Chelsea','East Village','Flatiron','Nomad','Gramercy Park','Greenwich Village',
'Noho', 'Little Italy', 'Lower East Side','Nolita', 'Soho', 'Hudson Square', 'Midtown', 'Kips Bay',
'Murray Hill','Midtwon South','Hells Kitchen', 'Hudson Yards','Chinatown','Tribeca']
len(myinterest)
# Out:
# 21

# %%
# 
discountDF = pd.read_csv('rentData/discountShare_TwoBd.csv')
priceDF = pd.read_csv('rentData/medianAskingRent_TwoBd.csv')
inventoryDf = pd.read_csv('rentData/rentalInventory_TwoBd.csv')

priceDF1 = priceDF[priceDF['areaName'].isin(myinterest)].set_index('areaName')

# Last 6 months 
pastsix = priceDF1.loc[:,'2022-02':'2022-07'] 
pastsix['Price'] = pastsix.mean(axis=1)
pastsix

discountDF
# Out:
#                 areaName    Borough      areaType  2010-01  2010-02  2010-03  \
# 0           All Downtown  Manhattan     submarket    0.106    0.086    0.097
# 1            All Midtown  Manhattan     submarket    0.118    0.066    0.096
# 2    All Upper East Side  Manhattan     submarket    0.134    0.093    0.113
# 3    All Upper Manhattan  Manhattan     submarket    0.073    0.092    0.107
# 4    All Upper West Side  Manhattan     submarket    0.084    0.103    0.094
# ..                   ...        ...           ...      ...      ...      ...
# 193      Windsor Terrace   Brooklyn  neighborhood      NaN      NaN      NaN
# 194            Woodhaven     Queens  neighborhood      NaN      NaN      NaN
# 195             Woodlawn      Bronx  neighborhood      NaN      NaN      NaN
# 196             Woodside     Queens  neighborhood      NaN      NaN      NaN
# 197            Woodstock      Bronx  neighborhood      NaN      NaN      NaN
#
# ...

# %%
inventory = inventoryDf[inventoryDf['areaName'].isin(myinterest)].set_index('areaName')
inventory = inventory.loc[:,'2022-02':'2022-07']
inventory['Inventory'] =inventory.mean(axis=1)
inventory
# Out:
#                    2022-02  2022-03  2022-04  2022-05  2022-06  2022-07  \
# areaName
# Chelsea              104.0    114.0    112.0    130.0    153.0    154.0
# Chinatown             13.0     18.0     18.0     14.0     17.0     14.0
# East Village         160.0    217.0    281.0    332.0    406.0    443.0
# Flatiron              57.0     80.0     89.0     90.0    101.0    106.0
# Gramercy Park         33.0     38.0     41.0     63.0     56.0     62.0
# Greenwich Village     41.0     40.0     58.0     79.0     86.0    106.0
# Little Italy          15.0     13.0     11.0     18.0     24.0     28.0
# Lower East Side      136.0    173.0    190.0    222.0    224.0    250.0
# Midtown               60.0     80.0     67.0     72.0     76.0     85.0
# Nolita                15.0     26.0     37.0     33.0     57.0     76.0
# Soho                  44.0     42.0     59.0     64.0     74.0     68.0
# Tribeca               45.0     41.0     34.0     59.0     77.0     79.0
#
# ...

# %%
from dis import dis


def sixmonthAVG(hoodsOfInterest): 
    discountDF = pd.read_csv('rentData/discountShare_TwoBd.csv')
    priceDF = pd.read_csv('rentData/medianAskingRent_TwoBd.csv')
    inventoryDF = pd.read_csv('rentData/rentalInventory_TwoBd.csv')

    
    
    # Initilalize DataFrame
    result = pd.DataFrame()

    # Inventory avg (1st column)
    inventoryDF = inventoryDF[inventoryDF['areaName'].isin(hoodsOfInterest)].set_index('areaName')
    result['AVG Inventory'] = inventoryDF.loc[:,'2022-02':'2022-07'].mean(axis=1)

    # Price avg
    priceDF = priceDF[priceDF['areaName'].isin(hoodsOfInterest)].set_index('areaName')
    result['AVG Price'] = priceDF.loc[:,'2022-02':'2022-07'].mean(axis=1)

    # Discount Avg
    discountDF = discountDF[discountDF['areaName'].isin(hoodsOfInterest)].set_index('areaName')
    result['AVG Price Reduction'] = discountDF.loc[:,'2022-02':'2022-07'].mean(axis=1)

    return result

sixmonthAVG(myinterest)
# Out:
#                    AVG Inventory     AVG Price  AVG Price Reduction
# areaName
# Chelsea               127.833333   7184.666667             0.166833
# Chinatown              15.666667   3449.666667             0.047600
# East Village          306.500000   4297.000000             0.128167
# Flatiron               87.166667   8693.500000             0.197833
# Gramercy Park          48.833333   4940.000000             0.109000
# Greenwich Village      68.333333   6815.666667             0.099833
# Little Italy           18.166667   4036.666667             0.057400
# Lower East Side       199.166667   4268.333333             0.115333
# Midtown                73.333333   6913.166667             0.137167
# Nolita                 40.666667   4997.500000             0.118333
# Soho                   58.500000   8532.500000             0.105167
# Tribeca                55.833333  10216.666667             0.114500
